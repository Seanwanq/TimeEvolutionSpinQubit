# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
import cat_state_tool as ct
import numpy as np

# %%
def gamma(t):
    return 0.05 * t

# %%
hilbert_dimension = 100
time_total = 40.0
time_steps = 2000
kappa = 0.04
omega_r = 1.0

# %%
system = ct.TimeDependentCatStateEvolution(
    hilbert_dimension, time_total, time_steps, kappa, omega_r, gamma
)

# %%
density_matrix_history, times = system.simulation_evolution()
# Out:
# 100%|██████████| 2000/2000 [01:13<00:00, 27.16it/s]

# %%
xvec = np.linspace(-14, 14, 150)
pvec = np.linspace(-14, 14, 150)

# %%
system.plot_wigner_2d_multi(density_matrix_history, xvec, pvec, 100, "develop/wigner_2d")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 system.plot_wigner_2d_multi(density_matrix_history, xvec, pvec, 100, "develop/wigner_2d")
#
# File c:\Users\seanw\OneDrive\Files\Master EXPH\Master Thesis\Works\Version_9_Jan_2025_CatCodeDrive\cat_state_tool.py:241, in TimeDependentCatStateEvolution.plot_wigner_2d_multi(self, density_matrix_history, xvec, pvec, frame_number, filename)
#     238 import gc
#     239 gc.collect()
# --> 241 with plt.figure(figsize=(10, 8)) as fig:
#     242     ax = fig.add_subplot(111)
#     245 fig, ax = plt.subplots(figsize=(10, 8))
#
# TypeError: 'Figure' object does not support the context manager protocol
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ct.animate_wigner_2d("develop")
# Out:
# MoviePy - Building video wigner_2d.mp4.
# MoviePy - Writing video wigner_2d.mp4
# MoviePy - Done !
# MoviePy - video ready wigner_2d.mp4
